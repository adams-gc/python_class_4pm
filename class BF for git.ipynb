# %% [markdown]
# #adv of vcs
# - tracks the hestry of our code
# - help to collaborate in team
# - maintain the code version
# # version control system
# - git ,google vcs etc .are mostely used
# - also store data in google cloud .
# # git command
# - git config--global user.name
# - git config --global user. email:adamsgc99@gmail.com
# - # in git
# - command
# - git init(
# - git add(add all the changes)
# - git commit -m 'commit massage'
# …or create a new repository on the command line
# echo "# BF-python-class" >> README.md
# git init
# git add README.md
# git commit -m "first commit"
# git branch -M main
# git remote add origin https://github.com/adams-gc/BF-python-class.git
# git push -u origin main
# …or push an existing repository from the command line
# git remote add origin https://github.com/adams-gc/BF-python-class.git
# git branch -M main
# git push -u origin main
# …or import code from another repository
# You can initialize this repository with code from a Subversion, Mercurial
# -

# %% [markdown]
# # What if there was no version control system?
# => If there was no VCS then we would have to copy/paste the codes or use google drives for code sharing
#
# # Advantages of using version control system (VCS)
# => Tracks the history of your entire codebase
# => It helps to collaborate in a team
# => Maintain the code version
#
# # Version control Systems => git, mercurial, google vcs
#
# # We should also keep our code somewhere in the cloud. It would be if the cloud supports git
# # That's why we use GitHub
#
#
# # Git Commands
# 1. git config --global user.name username
#     => Sets the global git username
# 2. git config --global user.email email
#     => Sets the global git email
#
# 3. git config --global user.name
#     => Checks whether the username is set or not
# 4. git config --global user.email
#     => Checks whether the email is set or not
#
#
# # In git the project folder is called git repository (repo)
#
# 1. git init
#     => Initializes a repo in local
#
# 2. git add .
#     => adds all the changes to the staging area
#
# # If you do not want to push any file or folder to github then mention thosefiles or folder in ".gitignore"
#
# 3. git commit -m "commit message"
#
# 4. git branch -M main
#     => Changes the master branch to main
#
# 5. git push -u origin <branch_name>

# %%
adams@ADAMS MINGW64 ~ (main)
$ git init
Reinitialized existing Git repository in C:/Users/adams/.git/

adams@ADAMS MINGW64 ~ (main)
$ git add*
git: 'add*' is not a git command. See 'git --help'.

The most similar command is
        add

adams@ADAMS MINGW64 ~ (main)
$ git add *

adams@ADAMS MINGW64 ~/PycharmProjects/pythonProject (master)
$ git commit -m "frist coommit"
[master (root-commit) 490222a] frist coommit
 29 files changed, 8722 insertions(+)
 create mode 100644 BF DAY 5.ipynb
 create mode 100644 CLASS  B.F.ipynb
 create mode 100644 DICTIONARY.ipynb
 create mode 100644 FUNCTION.ipynb
 create mode 100644 SET.ipynb
 create mode 100644 TUPLS.ipynb
 create mode 100644 Untitled.ipynb
 create mode 100644 Untitled1.ipynb
 create mode 100644 WHILE LOOP.ipynb
 create mode 100644 __pycache__/operator.cpython-39.pyc
 create mode 100644 class BF for git.ipynb
 create mode 100644 csv  adn pandas.ipynb
 create mode 100644 csvfile.csv
 create mode 100644 csvfile.json
 create mode 100644 csvfile.xml
 create mode 100644 data science string, exception.ipynb
 create mode 100644 data.csv
 create mode 100644 day6bf.ipynb
 create mode 100644 day7bf.ipynb
 create mode 100644 day9bf.ipynb
 create mode 100644 demo.ipynb
 create mode 100644 file handaling handaling pandas( and pandas).ipynb
 create mode 100644 filter.csv
 create mode 100644 list.ipynb
 create mode 100644 list_data
 create mode 100644 list_data.csv
 create mode 100644 pandas practice .ipynb
 create mode 100644 string pracitc question.ipynb
 create mode 100644 string.ipynb

adams@ADAMS MINGW64 ~/PycharmProjects/pythonProject (master)
$
